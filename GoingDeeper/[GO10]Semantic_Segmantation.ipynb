# %% [markdown]
# <a href="https://colab.research.google.com/github/zzocojoa/AIFFEL_EXP.github.io/blob/main/GoingDeeper/%5BGO10%5DSemantic_Segmantation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 도로 영역 찾기 - Segmentation model

# %% [markdown]
# **Semantic Segmentation**(시맨틱 세그멘테이션) 을 이용해서 자율주행차량이 주행해야 할 도로 영역을 찾는 상황을 가정하고 모델을 만들어보는 시간을 갖겠습니다. 앞서 강의 노드에서는 Semantic Segmentation을 위한 다양한 모델을 배워보았습니다. 이번 시간에는 U-Net을 사용해서 이미지가 입력되면 도로의 영역을 Segmentation 하는 모델을 만들어보겠습니다.

# %% [markdown]
# 최종적으로 만들어 볼 모델은 아래와 같습니다! 입력 이미지 위에 도로 영역으로 인식한 영역을 흰색으로 오버레이 한 이미지입니다.

# %% [markdown]
# ![](https://d3s0tskafalll9.cloudfront.net/media/original_images/result.gif)

# %% [markdown]
# ### 실습목표
# ___
#
# - 시맨틱 세그멘테이션 데이터셋을 전처리 가능
# - 시맨틱 세그멘테이션 모델을 만들고 학습 가능
# - 시맨틱 세그멘테이션 모델의 결과를 시각화 가능

# %% [markdown]
# ### 학습내용
# ___
#
# 1. 시맨틱 세그멘테이션 데이터셋
# 2. 시맨틱 세그멘테이션 모델
# 3. 시맨틱 세그멘테이션 모델 시각화

# %% [markdown]
# ## 1. Semantic Segmentation dataset

# %% [markdown]
# ### 이미지, 데이터 가져오기
# ___
#
# 먼저 시맨틱 `세그멘테이션(semantic segmentation)` 으로 도로의 영역을 분리하기 위해서는 도로의 영역을 라벨로 가진 데이터셋을 가지고 학습할 수 있도록 파싱 해야 합니다. 아래 링크를 통해서 물체 검출(object detection)으로 사용했던 `KITTI 데이터셋의 세그멘테이션 데이터` 를 다운로드합니다.

# %% [markdown]
# 데이터 출처: [The KITTI Vision Benchmark Suite](http://www.cvlibs.net/datasets/kitti/eval_semantics.php)

# %% [markdown]
# 아래는 데이터셋에서 확인할 수 있는 이미지와 라벨입니다. 지금까지 보던 라벨 데이터와 다르게 세그멘테이션 데이터는 이미지 형태의 라벨로 되어있습니다.

# %% [markdown]
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/000002_10.max-800x600.png)
# [KITTI dataset]

# %% [markdown]
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/000002_10_label.max-800x600.png)
# [KITTI dataest segmentation]

# %% [markdown]
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/000002_10_mqPgQu0.max-800x600.png)
# [KITTI dataset segmentation_rgb]

# %% [markdown]
# ### Question 1.
# ___
#
# 시맨틱 세그멘테이션의 이미지 라벨의 각 pixel 값은 의미를 갖습니다. 그렇다면 오늘 우리가 시맨틱 세그멘테이션으로 찾아내야 할 도로의 label은 어떤 값일까요?
#
# > 7

# %% [markdown]
# ### data loader 만들기
# ___
#
#  이미지와 데이터셋이 주어졌으니 모델을 학습시킬 수 있는 데이터 로더(data loader)를 만들어봅시다. 로더는 입력값 `(224, 224)`, 출력값 `(224, 244)` 크기를 갖는 모델을 학습시킬 수 있도록 데이터셋을 파싱 해야 합니다.

# %% [markdown]
# 이때 데이터 로더에 **augmentation** 을 적용해 봅시다. 오늘은 파이썬에서 많이 사용되는 `albumentations`을 사용해 보겠습니다. 하지만 Augmentation의 경우 `imgaug` 등 다른 라이브러리를 활용하셔도 됩니다.
#
# 또한 학습셋의 일정량을 **검증 데이터셋(validation dataset)** 으로 활용할 수 있도록 해야 합니다.
#
# 구현을 할 때는 아래 자료를 참고해보세요.
#
# - [Keras Sequence에 기반한 Dataloader](https://hwiyong.tistory.com/241)
# - [Albumentation을 적용한 Keras sequence](https://medium.com/the-artificial-impostor/custom-image-augmentation-with-keras-70595b01aeac)

# %% [markdown]
# 만든 후에는 직접 데이터셋이 잘 파싱 되어 나오는지 꼭 확인해보세요. 데이터셋에 오류가 없어야 성능이 안 나오더라도 문제를 찾아내기 쉽습니다.

# %%
# %pip list | grep tensorflow
# Out:
# tensorflow                    2.8.0
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.8.0
# tensorflow-gcs-config         2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.24.0
# tensorflow-metadata           1.7.0
# tensorflow-probability        0.16.0

# %%
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %% [markdown]
# Albumentation 의 사용법을 간단히 알아보겠습니다. 아래는 Albumentation에서 다양한 augmentation 기법을 확률적으로 적용할 수 있게 해주는 `Compose()`의 활용예입니다. imgaug의 `Sometimes()`와 유사한 기능입니다.

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
dir_path = '/content/drive/MyDrive/AIFFEL/data/semantic_segmentation/data/training'

augmentation_train = build_augmentation()
augmentation_test = build_augmentation(is_train=False)
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation_test(**image_data)
    processed = augmentation_train(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()

# %% [markdown]
# 이제 데이터셋을 구성해 봅시다. 이번에는 tf.keras.utils.Sequence를 상속받은 generator 형태로 데이터를 구성해 보겠습니다.

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=16,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ## 2. Semantic Segmentation Model

# %% [markdown]
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/u-net_1kfpgqE.max-800x600.png)

# %% [markdown]
# ### 모델 구조 만들기
# ___
#
# 시맨틱 세그멘테이션을 위한 모델을 만들어주세요. 세그멘테이션 모델 중 구조상 비교적 구현이 단순한 `U-Net`을 구현해 봅시다.
#
# 이때 입력 이미지의 크기는 위에서 만든 데이터셋에 맞춰서 만들어주세요.
#
# 사용에 필요한 레이어와 연산은 다음과 같습니다. 그리고 필요에 따라서 Dropout 등의 다른 레이어를 적용해 보세요.
#
# - `Conv2D`, `Conv2DTranspose`, `MaxPooling2D`, `concatenate`

# %%
def build_model(input_shape=(224, 224, 3)):
  inputs = Input(input_shape)
	
  #Contracting Path
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
  drop4 = Dropout(0.5)(conv4)
  pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)
  
  #Expanding Path
  drop5 = Dropout(0.5)(conv5)
  up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
  merge6 = concatenate([drop4,up6], axis = 3)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
  up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
  merge7 = concatenate([conv3,up7], axis = 3)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
  up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
  merge8 = concatenate([conv2,up8], axis = 3)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
  up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
  merge9 = concatenate([conv1,up9], axis = 3)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
  conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
  conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

  model = Model(inputs = inputs, outputs = conv10)
  return model

# %%
unet = build_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 28, 28, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 1024  9438208     ['conv2d_8[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 14, 14, 1024  0           ['conv2d_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  2097664    ['dropout_1[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['dropout[0][0]',
#                                 )                                 'conv2d_transpose[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  524544     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  131200     ['conv2d_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_3[0][0]',
#                                 6)                                'conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  32832      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_transpose_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 224, 224, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 224, 224, 2)  1154        ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 1)  3           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 모델 학습하기
# ___
#
# 이제 모델을 만들었으니 위에서 만들어본 데이터셋과 학습을 해봅시다.

# %%
model_path = '/content/drive/MyDrive/AIFFEL/data/semantic_segmentation/data/seg_model_unet.h5'
model = build_model()
model.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
model.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 11/11 [==============================] - 12s 1s/step - loss: 0.6930 - val_loss: 0.6926
# Epoch 2/100
# 11/11 [==============================] - 6s 572ms/step - loss: 0.6924 - val_loss: 0.6921
# Epoch 3/100
# 11/11 [==============================] - 6s 573ms/step - loss: 0.6918 - val_loss: 0.6916
# Epoch 4/100
# 11/11 [==============================] - 6s 577ms/step - loss: 0.6913 - val_loss: 0.6910
# Epoch 5/100
# 11/11 [==============================] - 6s 579ms/step - loss: 0.6908 - val_loss: 0.6905
# Epoch 6/100
# 11/11 [==============================] - 6s 580ms/step - loss: 0.6902 - val_loss: 0.6900
# Epoch 7/100
# 11/11 [==============================] - 6s 581ms/step - loss: 0.6897 - val_loss: 0.6894
# Epoch 8/100
# 11/11 [==============================] - 6s 582ms/step - loss: 0.6892 - val_loss: 0.6889
# Epoch 9/100
# 11/11 [==============================] - 6s 584ms/step - loss: 0.6887 - val_loss: 0.6884
# Epoch 10/100
# 11/11 [==============================] - 6s 585ms/step - loss: 0.6881 - val_loss: 0.6879
# Epoch 11/100
# 11/11 [==============================] - 6s 588ms/step - loss: 0.6876 - val_loss: 0.6873
# Epoch 12/100
# 11/11 [==============================] - 6s 589ms/step - loss: 0.6870 - val_loss: 0.6868
# Epoch 13/100
# 11/11 [==============================] - 6s 589ms/step - loss: 0.6866 - val_loss: 0.6863
# Epoch 14/100
# 11/11 [==============================] - 7s 592ms/step - loss: 0.6860 - val_loss: 0.6858
# Epoch 15/100
# 11/11 [==============================] - 7s 592ms/step - loss: 0.6855 - val_loss: 0.6852
# Epoch 16/100
# 11/11 [==============================] - 7s 592ms/step - loss: 0.6850 - val_loss: 0.6847
# Epoch 17/100
# 11/11 [==============================] - 7s 594ms/step - loss: 0.6844 - val_loss: 0.6842
# Epoch 18/100
# 11/11 [==============================] - 7s 595ms/step - loss: 0.6840 - val_loss: 0.6837
# Epoch 19/100
# 11/11 [==============================] - 7s 596ms/step - loss: 0.6833 - val_loss: 0.6832
# Epoch 20/100
# 11/11 [==============================] - 7s 597ms/step - loss: 0.6829 - val_loss: 0.6826
# Epoch 21/100
# 11/11 [==============================] - 7s 597ms/step - loss: 0.6824 - val_loss: 0.6821
# Epoch 22/100
# 11/11 [==============================] - 7s 598ms/step - loss: 0.6818 - val_loss: 0.6816
# Epoch 23/100
# 11/11 [==============================] - 7s 599ms/step - loss: 0.6812 - val_loss: 0.6811
# Epoch 24/100
# 11/11 [==============================] - 7s 599ms/step - loss: 0.6807 - val_loss: 0.6806
# Epoch 25/100
# 11/11 [==============================] - 7s 600ms/step - loss: 0.6802 - val_loss: 0.6800
# Epoch 26/100
# 11/11 [==============================] - 7s 600ms/step - loss: 0.6797 - val_loss: 0.6795
# Epoch 27/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6792 - val_loss: 0.6790
# Epoch 28/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.6787 - val_loss: 0.6785
# Epoch 29/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.6782 - val_loss: 0.6780
# Epoch 30/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6777 - val_loss: 0.6774
# Epoch 31/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6771 - val_loss: 0.6769
# Epoch 32/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6766 - val_loss: 0.6764
# Epoch 33/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6760 - val_loss: 0.6758
# Epoch 34/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6755 - val_loss: 0.6753
# Epoch 35/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6749 - val_loss: 0.6748
# Epoch 36/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6743 - val_loss: 0.6743
# Epoch 37/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6738 - val_loss: 0.6737
# Epoch 38/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.6730 - val_loss: 0.6733
# Epoch 39/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.6733 - val_loss: 0.6728
# Epoch 40/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6723 - val_loss: 0.6723
# Epoch 41/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.6721 - val_loss: 0.6718
# Epoch 42/100
# 11/11 [==============================] - 7s 601ms/step - loss: 0.6715 - val_loss: 0.6713
# Epoch 43/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.6710 - val_loss: 0.6708
# Epoch 44/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6704 - val_loss: 0.6703
# Epoch 45/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6699 - val_loss: 0.6697
# Epoch 46/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6693 - val_loss: 0.6692
# Epoch 47/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6689 - val_loss: 0.6687
# Epoch 48/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6683 - val_loss: 0.6682
# Epoch 49/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6679 - val_loss: 0.6677
# Epoch 50/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6672 - val_loss: 0.6672
# Epoch 51/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6668 - val_loss: 0.6667
# Epoch 52/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6665 - val_loss: 0.6662
# Epoch 53/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6657 - val_loss: 0.6657
# Epoch 54/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6651 - val_loss: 0.6652
# Epoch 55/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6647 - val_loss: 0.6647
# Epoch 56/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6644 - val_loss: 0.6642
# Epoch 57/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6637 - val_loss: 0.6637
# Epoch 58/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6634 - val_loss: 0.6631
# Epoch 59/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6625 - val_loss: 0.6626
# Epoch 60/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6621 - val_loss: 0.6621
# Epoch 61/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6617 - val_loss: 0.6616
# Epoch 62/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6613 - val_loss: 0.6611
# Epoch 63/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6605 - val_loss: 0.6606
# Epoch 64/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6602 - val_loss: 0.6601
# Epoch 65/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6596 - val_loss: 0.6596
# Epoch 66/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6593 - val_loss: 0.6591
# Epoch 67/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6588 - val_loss: 0.6586
# Epoch 68/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6582 - val_loss: 0.6581
# Epoch 69/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.6575 - val_loss: 0.6576
# Epoch 70/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.6574 - val_loss: 0.6571
# Epoch 71/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6569 - val_loss: 0.6566
# Epoch 72/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6559 - val_loss: 0.6561
# Epoch 73/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6558 - val_loss: 0.6556
# Epoch 74/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6552 - val_loss: 0.6551
# Epoch 75/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6546 - val_loss: 0.6546
# Epoch 76/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6540 - val_loss: 0.6541
# Epoch 77/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6535 - val_loss: 0.6536
# Epoch 78/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6527 - val_loss: 0.6531
# Epoch 79/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.6523 - val_loss: 0.6526
# Epoch 80/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6520 - val_loss: 0.6521
# Epoch 81/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6516 - val_loss: 0.6516
# Epoch 82/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6512 - val_loss: 0.6511
# Epoch 83/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6506 - val_loss: 0.6506
# Epoch 84/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6502 - val_loss: 0.6501
# Epoch 85/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6494 - val_loss: 0.6496
# Epoch 86/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6494 - val_loss: 0.6492
# Epoch 87/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6487 - val_loss: 0.6487
# Epoch 88/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6484 - val_loss: 0.6482
# Epoch 89/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6480 - val_loss: 0.6477
# Epoch 90/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6470 - val_loss: 0.6472
# Epoch 91/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6465 - val_loss: 0.6467
# Epoch 92/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6459 - val_loss: 0.6462
# Epoch 93/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6459 - val_loss: 0.6457
# Epoch 94/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6448 - val_loss: 0.6452
# Epoch 95/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6448 - val_loss: 0.6447
# Epoch 96/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6440 - val_loss: 0.6442
# Epoch 97/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6436 - val_loss: 0.6437
# Epoch 98/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6433 - val_loss: 0.6433
# Epoch 99/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6428 - val_loss: 0.6428
# Epoch 100/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6421 - val_loss: 0.6423

# %%
def build_unet_plus(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)
    
    # X0,0
    conv0_0 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv0_0 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_0)
    pool0_0 = MaxPooling2D(pool_size=(2, 2))(conv0_0)
    # X1,0
    conv1_0 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool0_0)
    conv1_0 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1_0)
    pool1_0 = MaxPooling2D(pool_size=(2, 2))(conv1_0)
    # X2,0
    conv2_0 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1_0)
    conv2_0 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2_0)
    pool2_0 = MaxPooling2D(pool_size=(2, 2))(conv2_0)
    # X3,0
    conv3_0 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2_0)
    conv3_0 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3_0)
    pool3_0 = MaxPooling2D(pool_size=(2, 2))(conv3_0)
    # X4,0
    conv4_0 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3_0)  
    conv4_0 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4_0)

    # X0,1
    up1_0 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv1_0)) 
    merge0_1 = concatenate([up1_0, conv0_0], axis = 3)
    conv0_1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge0_1)
    conv0_1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_1)
    # X1,1
    up2_0 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2_0))
    merge1_1 = concatenate([up2_0, conv1_0], axis = 3)
    conv1_1 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge1_1)
    conv1_1 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1_1)
    # X2,1
    up3_0 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv3_0))
    merge2_1 = concatenate([up3_0, conv2_0], axis = 3)
    conv2_1 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge2_1)
    conv2_1 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2_1)
    # X3,1
    up4_0 = Conv2D(512, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv4_0))
    merge3_1 = concatenate([up4_0, conv3_0], axis = 3)
    conv3_1 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge3_1)
    conv3_1 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3_1)  
    
    # X0,2
    up1_1 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv1_1)) 
    merge0_2 = concatenate([up1_1, conv0_0, conv0_1], axis = 3)
    conv0_2 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge0_2)
    conv0_2 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_2)
    # X1,2
    up2_1 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2_1))
    merge1_2 = concatenate([up2_1, conv1_0, conv1_0], axis = 3)
    conv1_2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge1_2)
    conv1_2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1_2)
    # X2,2
    up3_1 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv3_1))
    merge2_2 = concatenate([up3_1, conv2_0, conv2_1], axis = 3)
    conv2_2 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge2_2)
    conv2_2 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2_2)

    # X0,3
    up1_2 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv1_2)) 
    merge0_3 = concatenate([up1_2, conv0_0, conv0_1, conv0_2], axis = 3)
    conv0_3 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge0_3)
    conv0_3 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_3)
    # X1,3
    up2_2 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2_2))
    merge1_3 = concatenate([up2_2, conv1_0, conv1_1, conv1_2], axis = 3)
    conv1_3 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge1_3)
    conv1_3 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1_3)
    
    # X0,4
    up1_3 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv1_3)) 
    merge0_4 = concatenate([up1_3, conv0_0, conv0_1, conv0_2, conv0_3], axis = 3)
    conv0_4 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge0_4)
    conv0_4 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_4)
    
    output = Conv2D(1, 1, activation='sigmoid')(conv0_4)
    model = Model(inputs = inputs, outputs = output)
    
    return model

# %%
unet_plus = build_unet_plus()
unet_plus.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_61 (Conv2D)             (None, 224, 224, 64  1792        ['input_3[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_61[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 112, 112, 64  0          ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 112, 112, 12  73856       ['max_pooling2d_8[0][0]']
#                                 8)
#
#  conv2d_64 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_63[0][0]']
#                                 8)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 56, 56, 256)  295168      ['max_pooling2d_9[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_65[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 28, 28, 256)  0          ['conv2d_66[0][0]']
#  )
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 512)  1180160     ['max_pooling2d_10[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_67[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 14, 14, 512)  0          ['conv2d_68[0][0]']
#  )
#
#  conv2d_69 (Conv2D)             (None, 14, 14, 1024  4719616     ['max_pooling2d_11[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 14, 14, 1024  9438208     ['conv2d_69[0][0]']
#                                 )
#
#  up_sampling2d_13 (UpSampling2D  (None, 28, 28, 1024  0          ['conv2d_70[0][0]']
#  )                              )
#
#  conv2d_80 (Conv2D)             (None, 28, 28, 512)  2097664     ['up_sampling2d_13[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 1024  0           ['conv2d_80[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 56, 56, 512)  0          ['conv2d_68[0][0]']
#  )
#
#  conv2d_81 (Conv2D)             (None, 28, 28, 512)  4719104     ['concatenate_17[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 56, 56, 256)  524544      ['up_sampling2d_12[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_81[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 56, 56, 512)  0           ['conv2d_77[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 112, 112, 25  0          ['conv2d_66[0][0]']
#  )                              6)
#
#  up_sampling2d_16 (UpSampling2D  (None, 56, 56, 512)  0          ['conv2d_82[0][0]']
#  )
#
#  conv2d_78 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_16[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 112, 112, 12  131200      ['up_sampling2d_11[0][0]']
#                                 8)
#
#  conv2d_89 (Conv2D)             (None, 56, 56, 256)  524544      ['up_sampling2d_16[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_78[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 112, 112, 25  0           ['conv2d_74[0][0]',
#                                 6)                                'conv2d_64[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 224, 224, 12  0          ['conv2d_64[0][0]']
#  )                              8)
#
#  concatenate_20 (Concatenate)   (None, 56, 56, 768)  0           ['conv2d_89[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_15[0][0]']
#                                 8)
#
#  up_sampling2d_15 (UpSampling2D  (None, 112, 112, 25  0          ['conv2d_79[0][0]']
#  )                              6)
#
#  conv2d_71 (Conv2D)             (None, 224, 224, 64  32832       ['up_sampling2d_10[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 56, 56, 256)  1769728     ['concatenate_20[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_75[0][0]']
#                                 8)
#
#  conv2d_86 (Conv2D)             (None, 112, 112, 12  131200      ['up_sampling2d_15[0][0]']
#                                 8)
#
#  concatenate_14 (Concatenate)   (None, 224, 224, 12  0           ['conv2d_71[0][0]',
#                                 8)                                'conv2d_62[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_90[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 112, 112, 38  0           ['conv2d_86[0][0]',
#                                 4)                                'conv2d_64[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 224, 224, 64  73792       ['concatenate_14[0][0]']
#                                 )
#
#  up_sampling2d_14 (UpSampling2D  (None, 224, 224, 12  0          ['conv2d_76[0][0]']
#  )                              8)
#
#  up_sampling2d_18 (UpSampling2D  (None, 112, 112, 25  0          ['conv2d_91[0][0]']
#  )                              6)
#
#  conv2d_87 (Conv2D)             (None, 112, 112, 12  442496      ['concatenate_19[0][0]']
#                                 8)
#
#  conv2d_73 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_83 (Conv2D)             (None, 224, 224, 64  32832       ['up_sampling2d_14[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 112, 112, 12  131200      ['up_sampling2d_18[0][0]']
#                                 8)
#
#  conv2d_88 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_87[0][0]']
#                                 8)
#
#  concatenate_18 (Concatenate)   (None, 224, 224, 19  0           ['conv2d_83[0][0]',
#                                 2)                                'conv2d_62[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 112, 112, 51  0           ['conv2d_95[0][0]',
#                                 2)                                'conv2d_64[0][0]',
#                                                                   'conv2d_76[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 224, 224, 64  110656      ['concatenate_18[0][0]']
#                                 )
#
#  up_sampling2d_17 (UpSampling2D  (None, 224, 224, 12  0          ['conv2d_88[0][0]']
#  )                              8)
#
#  conv2d_96 (Conv2D)             (None, 112, 112, 12  589952      ['concatenate_22[0][0]']
#                                 8)
#
#  conv2d_85 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 224, 224, 64  32832       ['up_sampling2d_17[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_96[0][0]']
#                                 8)
#
#  concatenate_21 (Concatenate)   (None, 224, 224, 25  0           ['conv2d_92[0][0]',
#                                 6)                                'conv2d_62[0][0]',
#                                                                   'conv2d_73[0][0]',
#                                                                   'conv2d_85[0][0]']
#
#  up_sampling2d_19 (UpSampling2D  (None, 224, 224, 12  0          ['conv2d_97[0][0]']
#  )                              8)
#
#  conv2d_93 (Conv2D)             (None, 224, 224, 64  147520      ['concatenate_21[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 224, 224, 64  32832       ['up_sampling2d_19[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_93[0][0]']
#                                 )
#
#  concatenate_23 (Concatenate)   (None, 224, 224, 32  0           ['conv2d_98[0][0]',
#                                 0)                                'conv2d_62[0][0]',
#                                                                   'conv2d_73[0][0]',
#                                                                   'conv2d_85[0][0]',
#                                                                   'conv2d_94[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 224, 224, 64  184384      ['concatenate_23[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 224, 224, 64  36928       ['conv2d_99[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 224, 224, 1)  65          ['conv2d_100[0][0]']
#
# ==================================================================================================
# Total params: 36,157,953
# Trainable params: 36,157,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_plus_path = '/content/drive/MyDrive/AIFFEL/data/semantic_segmentation/data/seg_model_Plus_unet.h5'

unet_plus.compile(optimizer = Adam(learning_rate=1e-4, name='Adam'), loss = 'binary_crossentropy')

model.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

unet_plus.save(unet_plus_path)  # 학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 11/11 [==============================] - 15s 757ms/step - loss: 0.6418 - val_loss: 0.6418
# Epoch 2/100
# 11/11 [==============================] - 7s 593ms/step - loss: 0.6412 - val_loss: 0.6413
# Epoch 3/100
# 11/11 [==============================] - 7s 596ms/step - loss: 0.6405 - val_loss: 0.6408
# Epoch 4/100
# 11/11 [==============================] - 7s 600ms/step - loss: 0.6401 - val_loss: 0.6403
# Epoch 5/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6397 - val_loss: 0.6398
# Epoch 6/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6389 - val_loss: 0.6394
# Epoch 7/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.6388 - val_loss: 0.6389
# Epoch 8/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.6383 - val_loss: 0.6384
# Epoch 9/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.6378 - val_loss: 0.6379
# Epoch 10/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.6372 - val_loss: 0.6374
# Epoch 11/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6366 - val_loss: 0.6369
# Epoch 12/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6359 - val_loss: 0.6364
# Epoch 13/100
# 11/11 [==============================] - 7s 601ms/step - loss: 0.6358 - val_loss: 0.6360
# Epoch 14/100
# 11/11 [==============================] - 7s 600ms/step - loss: 0.6351 - val_loss: 0.6355
# Epoch 15/100
# 11/11 [==============================] - 7s 600ms/step - loss: 0.6348 - val_loss: 0.6350
# Epoch 16/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.6346 - val_loss: 0.6345
# Epoch 17/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.6340 - val_loss: 0.6340
# Epoch 18/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6333 - val_loss: 0.6335
# Epoch 19/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.6327 - val_loss: 0.6331
# Epoch 20/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.6322 - val_loss: 0.6326
# Epoch 21/100
# 11/11 [==============================] - 7s 610ms/step - loss: 0.6321 - val_loss: 0.6321
# Epoch 22/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6310 - val_loss: 0.6316
# Epoch 23/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6311 - val_loss: 0.6311
# Epoch 24/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6305 - val_loss: 0.6307
# Epoch 25/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6303 - val_loss: 0.6302
# Epoch 26/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6293 - val_loss: 0.6297
# Epoch 27/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6292 - val_loss: 0.6292
# Epoch 28/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6288 - val_loss: 0.6287
# Epoch 29/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6283 - val_loss: 0.6283
# Epoch 30/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6278 - val_loss: 0.6278
# Epoch 31/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6271 - val_loss: 0.6273
# Epoch 32/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6266 - val_loss: 0.6268
# Epoch 33/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6262 - val_loss: 0.6264
# Epoch 34/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6254 - val_loss: 0.6259
# Epoch 35/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6253 - val_loss: 0.6254
# Epoch 36/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6248 - val_loss: 0.6249
# Epoch 37/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6244 - val_loss: 0.6245
# Epoch 38/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6241 - val_loss: 0.6240
# Epoch 39/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6236 - val_loss: 0.6235
# Epoch 40/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6224 - val_loss: 0.6230
# Epoch 41/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6223 - val_loss: 0.6226
# Epoch 42/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6217 - val_loss: 0.6221
# Epoch 43/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6213 - val_loss: 0.6216
# Epoch 44/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6208 - val_loss: 0.6212
# Epoch 45/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6200 - val_loss: 0.6207
# Epoch 46/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6196 - val_loss: 0.6202
# Epoch 47/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6183 - val_loss: 0.6197
# Epoch 48/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6189 - val_loss: 0.6193
# Epoch 49/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.6186 - val_loss: 0.6188
# Epoch 50/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6180 - val_loss: 0.6183
# Epoch 51/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6176 - val_loss: 0.6178
# Epoch 52/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6170 - val_loss: 0.6174
# Epoch 53/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6168 - val_loss: 0.6169
# Epoch 54/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6163 - val_loss: 0.6164
# Epoch 55/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6159 - val_loss: 0.6160
# Epoch 56/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6152 - val_loss: 0.6155
# Epoch 57/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6150 - val_loss: 0.6150
# Epoch 58/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6143 - val_loss: 0.6146
# Epoch 59/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6131 - val_loss: 0.6141
# Epoch 60/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6132 - val_loss: 0.6136
# Epoch 61/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6133 - val_loss: 0.6132
# Epoch 62/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6123 - val_loss: 0.6127
# Epoch 63/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6123 - val_loss: 0.6122
# Epoch 64/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6110 - val_loss: 0.6118
# Epoch 65/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6103 - val_loss: 0.6113
# Epoch 66/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6104 - val_loss: 0.6108
# Epoch 67/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6094 - val_loss: 0.6104
# Epoch 68/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6097 - val_loss: 0.6099
# Epoch 69/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6091 - val_loss: 0.6095
# Epoch 70/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6088 - val_loss: 0.6090
# Epoch 71/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6089 - val_loss: 0.6085
# Epoch 72/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6073 - val_loss: 0.6081
# Epoch 73/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6072 - val_loss: 0.6076
# Epoch 74/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6069 - val_loss: 0.6071
# Epoch 75/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6058 - val_loss: 0.6067
# Epoch 76/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6058 - val_loss: 0.6062
# Epoch 77/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6052 - val_loss: 0.6058
# Epoch 78/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6043 - val_loss: 0.6053
# Epoch 79/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6045 - val_loss: 0.6048
# Epoch 80/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6036 - val_loss: 0.6044
# Epoch 81/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6032 - val_loss: 0.6039
# Epoch 82/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.6037 - val_loss: 0.6035
# Epoch 83/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6025 - val_loss: 0.6030
# Epoch 84/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6018 - val_loss: 0.6025
# Epoch 85/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6017 - val_loss: 0.6021
# Epoch 86/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.6013 - val_loss: 0.6016
# Epoch 87/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.6018 - val_loss: 0.6012
# Epoch 88/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5999 - val_loss: 0.6007
# Epoch 89/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.5995 - val_loss: 0.6003
# Epoch 90/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5992 - val_loss: 0.5998
# Epoch 91/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.5990 - val_loss: 0.5993
# Epoch 92/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5984 - val_loss: 0.5989
# Epoch 93/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5985 - val_loss: 0.5984
# Epoch 94/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.5980 - val_loss: 0.5980
# Epoch 95/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.5973 - val_loss: 0.5975
# Epoch 96/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.5961 - val_loss: 0.5971
# Epoch 97/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5967 - val_loss: 0.5966
# Epoch 98/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.5955 - val_loss: 0.5962
# Epoch 99/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.5950 - val_loss: 0.5957
# Epoch 100/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.5944 - val_loss: 0.5953

# %% [markdown]
# ## 3. Semantic Segmantation Model 시각화

# %% [markdown]
# 이번에는 학습한 모델의 결과를 눈으로 확인해 볼 차례입니다. 저장한 모델을 불러옵시다.

# %%
model_path = '/content/drive/MyDrive/AIFFEL/data/semantic_segmentation/data/seg_model_unet.h4'
model_plus_path = '/content/drive/MyDrive/AIFFEL/data/semantic_segmentation/data/seg_model_Plus_unet.h5'

model = tf.keras.models.load_model(model_path)
model_plus = tf.keras.models.load_model(model_plus_path)

# %% [markdown]
# 테스트 셋은 이미지를 제공하지만 정답 데이터를 제공하지 않으니 눈으로 확인할 수 있도록 모델이 추론(inference)한 결과를 우리의 눈으로 볼 수 있는 세그멘테이션 이미지로 만들어주세요!

# %% [markdown]
# 이때 입력 이미지와 라벨을 한 번에 볼 수 있도록 모델의 출력값을 입력 이미지 위에 겹쳐서 보이기, 즉 오버레이(overray) 해 주세요. PIL 패키지를 사용하신다면 Image.blend를 활용하실 수 있습니다.
#
# get_output이라는 이름의 함수로 만들어 주세요.

# %%
def get_output(model, preproc, image_path, output_path):
     origin_img = imread(image_path)
     data = {"image":origin_img}
     processed = preproc(**data)
     output = model(np.expand_dims(processed["image"]/255,axis=0))
     output = (output[0].numpy()>0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
     output = Image.fromarray(output)
     background = Image.fromarray(origin_img).convert('RGBA')
     output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
     output = Image.blend(background, output, alpha=0.5)
     output.show()
     return output

# %% [markdown]
# 위에서 작성한 함수를 이용해 시각화를 해봅시다.

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
get_output(
     model_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png'
 )
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7FAEBBDF7A90>

# %% [markdown]
# 세그멘테이션이 성능을 정량적으로 측정하기 위한 방법으로 IoU(Intersection over Union)를 계산하게 됩니다. IoU를 계산하는 방법은 지난 시간에 소개한 바 있으므로 해당 내용을 활용하여 구현해 보겠습니다.

# %% [markdown]
# IoU를 계산하려면 모델이 도로 영역이라고 판단한 부분이 1로, 나머지 부분이 0으로 표시된 행렬, 그리고 라벨 데이터에서 도로 영역이 1, 나머지 부분이 0으로 표시된 행렬이 필요합니다. 각각을 `prediction`, `target`이라고 불렀을 때 이를 계산하는 함수를 구현해 보겠습니다. 위에 구현했던 `get_output`을 좀 더 확장해서 output, prediction, target을 함께 리턴하도록 구현해 봅시다.

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 2    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.008055
# 0.0080545229244114

# %%
model_plus_iou = []

for i in range(50):  # 이미지 50개로 테스트
    # U-Net++의 IoU 계산
    output, prediction, target = get_output(
         model_plus, 
         test_preproc,
         image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
         output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
         label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
     )

    model_plus_iou.append(calculate_iou_score(target, prediction))
# Out:
# IoU : 0.002781
# IoU : 0.001063
# IoU : 0.008055
# IoU : 0.002104
# IoU : 0.000222
# IoU : 0.000126
# IoU : 0.000573
# IoU : 0.007957
# IoU : 0.011166
# IoU : 0.013497
# IoU : 0.010327
# IoU : 0.010184
# IoU : 0.010597
# IoU : 0.013257
# IoU : 0.004613
# IoU : 0.006367
# IoU : 0.008596
# IoU : 0.009576
# IoU : 0.005283
# IoU : 0.003174
# IoU : 0.004249
# IoU : 0.001630
# IoU : 0.004496
# IoU : 0.006527
# IoU : 0.004263
# IoU : 0.001819
# IoU : 0.003647
# IoU : 0.007730
# IoU : 0.011257
# IoU : 0.010919
# IoU : 0.009603
# IoU : 0.007379
# IoU : 0.004321
# IoU : 0.013015
# IoU : 0.002015
# IoU : 0.002063
# IoU : 0.001837
# IoU : 0.002101
# IoU : 0.003338
# IoU : 0.002435
# IoU : 0.000869
# IoU : 0.001444
# IoU : 0.001349
# IoU : 0.012445
# IoU : 0.011155
# IoU : 0.009378
# IoU : 0.011950
# IoU : 0.010817
# IoU : 0.018109
# IoU : 0.016834

# %%
plt.figure(figsize=(10,5))
plt.plot(model_plus_iou)
plt.title('IoU', fontsize=20)
plt.legend(['U-Net', 'U-Net++'])
plt.show()
